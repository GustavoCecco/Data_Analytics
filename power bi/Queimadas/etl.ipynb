# %%
import pandas as pd
import glob

pasta_arquivos = 'C:/Users/Gustavo/Downloads/Data_Analytics/power bi/Queimadas/*.csv'
arquivos_csv = glob.glob(pasta_arquivos)

arquivo_combinado = pd.concat((pd.read_csv(f, encoding="utf-8")for f in arquivos_csv), ignore_index=True)

arquivo_combinado.to_csv('C:/Users/Gustavo/Downloads/Data_Analytics/power bi/Queimadas/arquivo_combinado.csv', index=False, encoding="utf-8")
